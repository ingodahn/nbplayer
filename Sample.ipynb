# %% [markdown]
# # A Sample Notebook for the Notebook Player
# ## By Ingo Dahn
# This notebook comes as a sample with the Notebook Player. While there are no special requirements to notebooks to be processed by the player, the designation of pairs of consecutive markdown and code cells makes it possible to transfer basic data between converted notebooks. This sample notebook demonstrates the use of input and output cells.
#
# The first code cell initializes the notebook.

# %%
i=0
n=1
m=1
print('Notebook initialized')
# Out:
# Notebook initialized

# %% [markdown]
# <span class="nbdataIn">Eventually, the following cell modifies the notebook data after pasting results from previous runs of this or another notebook, either by pasting them from the clipboard or automatically.
#
# `<span class="nbdataIn"></span>` characterizes this cell as an **input cell**.</span>

# %%
#Paste status below this line

# Paste status above this line
print('Status restored')
# Out:
# Status restored

# %% [markdown]
# Let's do some calculations:

# %%
s=m+n
n=m
m=s
i=i+1
print('The Fibonacci numbers',i,'and',i+1,'are',n,'and',m)
# Out:
# The Fibonacci numbers 1 and 2 are 1 and 2

# %% [markdown]
# <span class="nbdataOut">**Output markdown cells** must have a node of the form `<span class="nbdataOut"></span>` This node may contain a list node `<ul></ul>` with child nodes `<li class="successor"><a>...</a></li>` where the `<a></a>` node links to a notebook with an input cell using these variables.
# <ul>
#     <li class="successor"><a href="./Sample.ipynb" target="_blank">The Sample Notebook</a>
# </ul>
# The following code cell generates the script to be pasted into the receiving input cell.
# </span>

# %%
print('i=',i)
print('n=',n)
print('m=',m)
# Out:
# i= 1
# n= 1
# m= 2

# %% [markdown]
# When the notebook has some unused autogenerated cells, some explanation should be given.
#
# The following cell is left blank for your own experiments.
